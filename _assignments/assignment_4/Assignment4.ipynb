# %% [markdown]
# # <span style="color:red"> Assignment 4 - Due Tuesday, February 24th at 8am ET</span>

# %% [markdown]
# <font size = "4">
#
# Complete the code cells in this Jupyter notebook, and submit the final .ipynb notebook to Gradescope.
#
# Please do the following in VS code before you submit:
#
# - Click "Clear All Outputs"
#
# - Click "Restart"
#
# - Run all code cells
#
# - Save the file
#
# **Note:** Output should match the code that appears in its corresponding cell.

# %% [markdown]
# <font size = "3">
#
# Import necessary libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### **(a)** For-loops and Conditional Statements
#
# Using the lists of movie ratings and titles below, where each rating corresponds directly to the title in the same position, create a new list of movies that are considered top picks (**those with ratings greater than or equal to 8**):
#
# - Use a for loop to iterate through both lists below and store the titles and ratings of movies considered top picks in two new lists:
#
#   - `top_picks_titles`: The titles of movies considered top picks.
#
#   - `top_picks_ratings`: The ratings of top pick movies.
# - Print the results of both lists.

# %%
# Run this cell first
movie_ratings = [6.8, 8.3, 8.5, 5.1, 8.0, 3.5, 7.8, 8.4, 7.8, 2.8, 8.8]
movie_titles = ["Barbie", "Oppenheimer", "Spider-Man: Across the Spider-Verse", 
                "Morbius", "Dune", "The Emoji Movie", 
                "Everything Everywhere All at Once", "Avengers: Endgame", 
                "The Batman", "Cats", "Pulp Fiction"]

# %%
# Write your answer here

top_picks_titles = []
top_picks_ratings = []

for i in range(len(movie_titles)):
    title = movie_titles[i]
    rating = movie_ratings[i]
    if rating >= 8.0:
        top_picks_titles = top_picks_titles + [title]
        top_picks_ratings = top_picks_ratings + [rating]

print(top_picks_titles)
print(top_picks_ratings)
# Out:
# ['Oppenheimer', 'Spider-Man: Across the Spider-Verse', 'Dune', 'Avengers: Endgame', 'Pulp Fiction']
# [8.3, 8.5, 8.0, 8.4, 8.8]

# %% [markdown]
# ### **(b)** Follow-up to Part **(a)**
#
# Using NumPy, do the following:
#
# 1. Convert the list `top_picks_ratings` you created in part (a) into a NumPy array named `top_ratings_arr`.
#
# 2. Define the following variables using the specified functions:
#
#    - `num_top`: total number of top-pick movies using `np.size()`
#
#    - `avg_top`: average rating using `np.mean()`
#    - `max_top`: highest rating using `np.max()`
#
# 3. Create a new NumPy array called `centered_ratings` that subtracts the mean (i.e. the value stored in `avg_top`) from each element/component of `top_ratings_arr`. Do so with **only one** subtraction operation.
#
# 4. Create a NumPy array called `above_average` that indicates which top-pick ratings are **strictly greater than** `avg_top`. The entries of this array will consist of the Boolean values `True` and `False`. This should be defined using a single logical comparison operator, not "manually".

# %%
# Write your answer here

top_ratings_arr = np.array(top_picks_ratings)
num_top = np.size(top_picks_titles)
avg_top = np.mean(top_picks_ratings)
max_top = np.max(top_picks_ratings)
centered_ratings = np.array(top_ratings_arr - avg_top)
above_average = np.array(top_picks_ratings) > avg_top

# %% [markdown]
# ### **(c)** For-loops + Plotting
#
# 1. Create an array of x-values (`vec_x`) with 100 evenly spaced points between 0 and 2π using `np.linspace()`.
#
# 2. Create three y-vectors:
#    - `vec_y1` using `np.sin(vec_x)`
#    - `vec_y2` using `np.cos(vec_x)`
#    - `vec_y3` using `np.sin(vec_x)` + `np.cos(vec_x)`
#
# 3. Create a list called `list_vectors` containing all three vectors: [`vec_y1`, `vec_y2`, `vec_y3`]
#
# 4. Write a for-loop that iterates through `list_vectors` and plots each y-vector against `vec_x` on the same plot.
#
# 5. Add axis labels, a title, and a legend (see the command `plt.legend`)
#
# **Note**: The final output should be a single 2D plot showing all three functions plotted against the same x-values. It should look something like this:
#
# <img src="figures/trig_functions.png" alt="drawing" width="350"/>

# %%
# Write your answer here

vec_x = np.linspace(0,2*np.pi,100)
vec_y1 = np.sin(vec_x)
vec_y2 = np.cos(vec_x)
vec_y3 = np.sin(vec_x) + np.cos(vec_x)
list_vectors = [vec_y1,vec_y2,vec_y3]
for vec_y in list_vectors:
    plt.plot(vec_x,vec_y)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title("Three Functions plotted against their X-values")
    plt.legend(["sin(x)","cos(x)","sin(x)+cos(x)"])

# %% [markdown]
# ### **(d)** Learn How to Use zip()
#
# - Below, write a `for` loop that prints out the average score for each player over the 3 rounds. The names and scores are given in the lists below.
#
# - The program should print the players's name and their average score, formatted like this:
#
#     ```python
#     John's average score: ___
#     Bob's average score: ___
#     Jane's average score: ___
#     Dave's average score: ___
#     Jenny's average score: ___
#     ```
#
# - Each printed average should be **rounded** to two digits after the decimal point.
#
# - Use the `zip` function in the heading of the loop. You will want to "zip" all four lists as follows:
#
# ```python
#         zip(player_names, round1, round2, round3)
# ```
#
# &ensp; Hints/Tips:
# - You can learn more about zip() here: [Python zip() Function](https://www.geeksforgeeks.org/zip-in-python/)
# - You can print a string followed by a float using print as follows:
# ```python
#     print(some_string, some_float)
# ```
# - ...or you can convert the float to a string using ``str``

# %%
# run this cell first
player_names = ["John", "Bob", "Jane", "Dave", "Jenny"]
round1 = [120, 200, 150, 300, 180]
round2 = [100, 210, 160, 280, 190]
round3 = [130, 190, 170, 310, 175]

# %%
# Write your answer here

for names,first,second,third in zip(player_names,round1,round2,round3):
    avg_score_1 = (round1[0] + round2[0] + round3[0]) / 3
    avg_score_2 = (round1[1] + round2[1] + round3[1]) / 3
    avg_score_3 = (round1[2] + round2[2] + round3[2]) / 3
    avg_score_4 = (round1[3] + round2[3] + round3[3]) / 3
    avg_score_5 = (round1[4] + round2[4] + round3[4]) / 3
print("John's average score: ", round(avg_score_1, 2))
print("Bob's average score: ", round(avg_score_2, 2))
print("Jane's average score: ", round(avg_score_3, 2))
print("Dave's average score: ", round(avg_score_4, 2))
print("Jenny's average score: ", round(avg_score_5, 2))
# Out:
# John's average score:  116.67
# Bob's average score:  200.0
# Jane's average score:  160.0
# Dave's average score:  296.67
# Jenny's average score:  181.67

# %% [markdown]
# ### **(e)** Looping Over Filenames
#
# Consider the following line of code

# %%
dataset = pd.read_csv('data/china_emission.csv')

# %% [markdown]
# There are two parts of the string: the **file path** "data/" and the **file name** "china_emission.csv"
#
# Using string concatenation, we could read in the file in following way:

# %%
file_path = 'data/'
file_name = 'china_emission.csv'

dataset = pd.read_csv(file_path + file_name)

# %% [markdown]
# Do the following:
#
# 1. If necessary, change the value of `file_path` so that you are able to run the above cell without any errors (for example, maybe you need to change it to "datasci151spring2026/_assignments/assignment_4/data/")
#
# 2. Import the `os` library. This is the operating system library. (I don't think a nickname is necessary for this one)
#
# 3. Use the function `os.listdir` to create a list containing all the file names inside the data folder. You should pass in the variable `file_path` to this function.
#
# 4. Create an empty list called `df_list`.
#
# 5. Write a for-loop that loops over the elements of the list you created with `os.listdir`. For each file:
#
# - Read in the file using `pd.read_csv()`, creating a Pandas DataFrame object.
#
# - Append the DataFrame object to `df_list`
#
# 6. After the loop:
# - Print the number of DataFrames in `df_list` using a suitable Python command
#
# - Print the shape of the first DataFrame. **Note:** Suppose a single DataFrame called `df` has been defined. You can determine its shape by typing `df.shape`

# %%
# Write your answer here

import os
File_list = os.listdir(file_path)
df_list = []
for file in File_list:
    df = pd.read_csv(file_path + file)
    df_list.append(df)
print(df_list)
print(df.shape)
# Out:
# [    Year  Energy_consumption  CO2_emission        GDP
# 0   1993           29.167379   1906.330547  17266.956
# 1   1994           28.844093   1874.631239  17693.238
# 2   1995           29.448324   1822.145843  17977.788
# 3   1996           29.885148   1844.026617  18130.194
# 4   1997           29.424506   1873.574701  18467.136
# 5   1998           29.312828   1814.587625  18800.136
# 6   1999           28.749909   1800.869327  19128.966
# 7   2000           28.789782   1733.541828  19728.210
# 8   2001           29.354761   1744.386980  20086.878
# 9   2002           28.930513   1776.033331  20053.488
# 10  2003           29.002340   1745.154476  19911.684
# 11  2004           29.115779   1747.739351  20049.936
# 12  2005           28.628384   1731.952257  20229.918
# 13  2006           29.155240   1688.628986  21040.056
# 14  2007           28.038245   1717.981584  21690.696
# 15  2008           28.590236   1664.515219  21838.992
# 16  2009           26.893887   1673.343490  20606.664
# 17  2010           28.337573   1563.453767  21439.992
# 18  2011           27.142187   1643.445728  22295.262
# 19  2012           27.445103   1586.979150  22432.518
# 20  2013           27.934929   1613.798693  22556.316
# 21  2014           27.019616   1643.699409  23053.392
# 22  2015           27.348639   1567.117382  23340.186
# 23  2016           27.518202   1575.496331  23839.422
# 24  2017           28.465500   1577.778791  24552.060
# 25  2018           27.720286   1610.118550  24823.080
# 26  2019           27.066602   1563.192451  25092.300,     Year  Energy_consumption  CO2_emission       GDP
# 0   1993           40.592725   2266.245223  25644.84
# 1   1994           42.057694   2259.987469  25894.62
# 2   1995           43.395716   2371.402973  26573.10
# 3   1996           44.208260   2393.458755  27411.18
# 4   1997           44.960528   2432.024380  27688.68
# 5   1998           44.079613   2440.623207  27323.64
# 6   1999           44.950012   2371.907688  27256.50
# 7   2000           45.065930   2450.472817  27997.74
# 8   2001           44.690456   2465.924114  28109.28
# 9   2002           44.343551   2451.642972  28110.72
# 10  2003           44.653769   2464.142800  28553.46
# 11  2004           45.247429   2542.978748  29168.34
# 12  2005           45.523596   2528.945605  29700.66
